# %%
import pandas as pd 
import numpy as np
import sqlite3
import networkx as nx
import matplotlib.pyplot as plt
import os 


os.chdir('/Users/kajaltiwary/ANLY_645_Project/')

# %%
#laod all the dataset 
Node = pd.read_csv('data/Node_info.csv')
Edge = pd.read_csv('data/Edge_info.csv')
dat2 = pd.read_csv('data/Song_attribute.csv')
Edge.head()
# Out:
#                           edge  edge_weight
# 0         ('Wale', 'Big Sean')          2.0
# 1     ('2 Chainz', 'Big Sean')          5.0
# 2    ('Rick Ross', 'Big Sean')          3.0
# 3  ('Young Money', 'Big Sean')          0.0
# 4  ('ScHoolboy Q', 'Big Sean')          0.0

# %%
#extrac the data needed 
Nodes = Node['node'].tolist()
Node_size = Node['node_size'].tolist()
Node_color = Node['node_color'].tolist()
print(Node_color)
Edges = Edge['edge'].tolist()

# Make edges tuples
new_edges = []
for x in Edges:
    x = x[1:-1]
    x = x.split(", ")
    z = []
    for y in x:
        y = y[1:-1]
        z.append(y)
    z = tuple(z)
    new_edges.append(z)
    
Edges = new_edges

Edge_weights = Edge['edge_weight'].tolist()
# Out:
# [4.0, 6.0, 9.0, 7.0, 10.0, 7.0, 7.0, 7.0, 4.0, 9.0, 8.0, 6.0, 6.0, 4.0, 3.0, 4.0, 5.0, 7.0, 5.0, 9.0, 7.0, 8.0, 8.0, 8.0, 5.0, 7.0, 6.0, 8.0, 7.0, 7.0, 9.0, 7.0, 8.0, 6.0, 3.0, 3.0, 7.0, 4.0, 7.0, 4.0, 4.0, 5.0, 9.0, 8.0, 8.0, 9.0, 6.0, 9.0, 10.0, 9.0, 6.0, 10.0, 9.0, 8.0, 7.0, 7.0, 8.0, 10.0, 9.0, 8.0, 10.0, 11.0, 7.0, 7.0, 12.0, 7.0, 8.0, 5.0, 10.0, 7.0, 7.0, 9.0, 2.0, 9.0, 7.0, 4.0, 6.0, 6.0, 4.0, 2.0, 5.0, 6.0, 4.0, 2.0, 2.0, 6.0, 6.0, 2.0, 4.0, 4.0, 7.0, 6.0, 7.0, 11.0, 8.0, 7.0, 7.0, 10.0, 6.0, 7.0, 8.0, 4.0, 6.0, 4.0, 3.0, 8.0, 6.0, 5.0, 5.0, 7.0, 6.0, 8.0, 5.0, 6.0, 8.0, 5.0, 6.0, 12.0, 8.0, 6.0, 9.0, 8.0, 12.0, 8.0, 6.0, 5.0, 7.0, 1.0, 1.0, 3.0, 3.0, 8.0, 3.0, 2.0, 2.0, 6.0, 6.0, 5.0, 9.0, 4.0, 4.0, 3.0, 9.0, 6.0, 4.0, 7.0, 10.0, 5.0, 3.0, 6.0, 5.0, 4.0, 7.0, 5.0, 7.0, 4.0, 3.0, 5.0, 3.0, 2.0, 5.0, 3.0, 2.0, 8.0, 5.0, 7.0, 7.0, 7.0, 7.0, 7.0, 6.0, 9.0, 6.0, 5.0, 2.0, 3.0, 6.0, 0.0, 5.0, 6.0, 2.0, 1.0, 5.0, 2.0, 2.0, 4.0, 4.0, 10.0, 2.0, 4.0, 3.0, 7.0, 2.0, 1.0, 1.0, 0.0, 2.0, 4.0, 4.0, 1.0, 3.0, 4.0, 1.0, 2.0, 5.0, 2.0, 6.0, 5.0, 3.0, 2.0, 4.0, 3.0, 4.0, 6.0, 4.0, 4.0, 8.0, 5.0, 7.0, 8.0, 5.0, 8.0, 5.0, 6.0, 6.0, 9.0, 7.0, 8.0, 3.0, 11.0, 2.0, 8.0, 3.0, 6.0, 7.0, 7.0, 6.0, 7.0, 5.0, 8.0, 6.0, 6.0, 4.0, 0.0, 6.0, 3.0, 1.0, 1.0, 4.0, 1.0, 6.0, 1.0, 2.0, 3.0, 3.0, 2.0, 5.0, 4.0, 3.0, 3.0, 3.0, 4.0, 7.0, 2.0, 3.0, 3.0, 5.0, 1.0, 4.0, 0.0, 9.0, 2.0, 2.0, 1.0, 3.0, 4.0, 1.0, 3.0, 3.0, 3.0, 5.0, 3.0, 5.0, 2.0, 2.0, 7.0, 6.0, 6.0, 3.0, 1.0, 3.0, 8.0, 7.0, 4.0, 5.0, 4.0, 3.0, 5.0, 6.0, 3.0, 4.0, 5.0, 4.0, 2.0, 3.0, 6.0, 1.0, 4.0, 1.0, 4.0, 2.0, 2.0, 3.0, 2.0, 5.0, 4.0, 3.0, 3.0, 6.0, 4.0, 5.0, 8.0, 3.0, 3.0, 1.0, 4.0, 4.0, 6.0, 3.0, 4.0, 1.0, 1.0, 1.0, 2.0, 3.0, 5.0, 4.0, 5.0, 6.0, 1.0, 2.0, 2.0, 4.0, 4.0, 3.0, 3.0, 3.0, 0.0, 6.0, 4.0, 3.0, 4.0, 5.0, 3.0, 3.0, 4.0, 1.0, 5.0, 5.0, 3.0, 3.0, 5.0, 2.0, 2.0, 3.0, 1.0, 3.0, 3.0, 5.0, 5.0, 5.0, 8.0, 8.0, 3.0, 7.0, 2.0, 2.0, 3.0, 1.0, 3.0, 1.0, 3.0, 2.0, 2.0, 4.0, 1.0, 6.0, 6.0, 8.0, 6.0, 5.0, 9.0, 3.0, 4.0, 8.0, 7.0, 3.0, 2.0, 3.0, 2.0, 3.0, 3.0, 2.0, 4.0, 2.0, 2.0, 3.0, 2.0, 1.0, 3.0, 5.0, 1.0, 2.0, 5.0, 6.0, 2.0, 4.0, 5.0, 6.0, 4.0, 6.0, 6.0, 5.0, 5.0, 5.0, 3.0, 8.0, 6.0, 3.0, 4.0, 6.0, 7.0, 3.0, 1.0, 1.0, 5.0, 5.0, 2.0, 3.0, 1.0]

# %%
#build up the network 
G = nx.Graph() 

#Prepare node attributesm it make take a whike 
#use dictionary to retreive all artists songs 
Art = {}
keys1 = list(Nodes)
#add sub dictionary for each artist 
for i in keys1:
    Art[i] = {}
#add each artists songs to their dictionaries 
for key in keys1:
    for index, rows in dat2.iterrows():
        if rows.artist == key:
            Art[key][rows.song_name] = rows.song_info


#add node and weight
for i in range(len(Nodes)):
    G.add_node(Nodes[i], weight = Node_size[i], songs = Art[Nodes[i]],diversity = Node_color[i])
#add edge and weight 
G.add_edges_from(Edges)

#make edge weights more mutual 
for i in range(len(Edge_weights)):
    if Edge_weights[i] == 0:
        Edge_weights[i] = 2
    elif Edge_weights[i] == 1:
        Edge_weights[i] = 3
    elif Edge_weights[i] == 2:
        Edge_weights[i] = 4
    elif Edge_weights[i] == 3:
        Edge_weights[i] = 5
    elif Edge_weights[i] > 3:
        Edge_weights[i] = 7

# %%
nx.draw(G)

# %% [markdown]
# # Network Analysis

# %%
import nx_tools as nxt
import shutil
import random
from importlib import reload  # Python 3.4+
import os
import seaborn as sns
import math

# Isolate GCC
Gcc = sorted(nx.connected_components(G), key=len, reverse=True)
G0 = G.subgraph(Gcc[0])

def build_output_folder(out_dir_path):
    if(os.path.exists(out_dir_path)):
        shutil.rmtree(out_dir_path)
    os.mkdir(out_dir_path)

output_folder="outputs"
build_output_folder(output_folder)

output_root = "network_analysis_cent_corr"
nxt.ave_degree(G0)
nxt.network_summary(G0)
nxt.plot_centrality_correlation(G0,path=output_folder+"/"+output_root+".pdf")
# Out:
# Average Degree:  6.0181818181818185
# GENERAL
# 	number of nodes: 440
# 	number of edges: 1324
# 	is_directed: False
# 	is_weighted: False
# 	number_connected_components 1
# 	number of triangle:  440
# 	density: 0.013708842410436944
# 	average_clustering coefficient:  0.31040074447036664
# 	degree_assortativity_coefficient:  -0.3829461447546472
# 	is_tree: False
# 	diameter: 8
# 	radius: 4
# 	average_shortest_path_length:  4.110861462000414
# DEGREE (NORMALIZED)
# 	min: 0.002277904328018223
# 	mean: 0.01370884241043694
# 	median: 0.004555808656036446
# 	max: 0.07744874715261958
# 	top nodes: ['PnB Rock', 'Lil Yachty', 'Freddie Gibbs', 'Quavo', 'Rick Ross', 'NAV']
# 	           [0.07744874715261958, 0.07517084282460136, 0.07289293849658314, 0.07289293849658314, 0.07061503416856492, 0.07061503416856492]
# CLOSENESS CENTRALITY
# 	min: 0.17128365197034726
# 	mean: 0.2487186347936966
# 	median: 0.2431459615992245
# 	max: 0.3526104417670683
# 	top nodes: ['2 Chainz', 'Big Sean', 'Rick Ross', 'Ty Dolla ign', 'Tory Lanez', 'PnB Rock']
# 	           [0.3526104417670683, 0.338473400154202, 0.33821263482280434, 0.33795227097767516, 0.33691481197237144, 0.33434881949733436]
# BETWEEN CENTRALITY
# 	min: 0.0
# 	mean: 0.007102423429224688
# 	median: 0.0
# 	max: 0.14615212462970273
# 	top nodes: ['G-Eazy', 'PnB Rock', 'Kanye West', 'Bazzi', 'Baby Keem', 'Rick Ross']
# 	           [0.14615212462970273, 0.10569781299823289, 0.08582167638448532, 0.08057660164417822, 0.07900499974555253, 0.07820995937527157]

# %% [markdown]
# # Community Detection

# %%
# Create Partitions
import itertools
partition_sequence = nx.community.girvan_newman(G0)
ps = []
k = round(G0.number_of_nodes()-1)
for i in range(0,k):
    
    ps.append(tuple(sorted(c) for c in next(partition_sequence)))

modularity_sequence = [nx.community.quality.modularity(G0, p) for p in ps]

# %%
plt.plot(modularity_sequence)
plt.ylabel('Modularity')
plt.xlabel('Algorithm step')
plt.savefig("community_detection_modularity_plot.png")

# %%
index_max = max(range(len(modularity_sequence)), key=modularity_sequence.__getitem__)
best_partition = ps[index_max]

def create_partition_map(partition):
    partition_map = {}
    for idx, cluster_nodes in enumerate(partition):
        for node in cluster_nodes:
            partition_map[node] = idx
    return partition_map
fig, ax = plt.subplots(figsize=(30,30))
best_partition_map = create_partition_map(best_partition)

node_colors = [best_partition_map[n] for n in G0.nodes()]
nx.draw(G0, with_labels=True, node_color=node_colors)
plt.savefig("communities.png")

# %%
nx.community.quality.modularity(G0, best_partition)
# Out:
# 0.6087918488330702

# %%
nx.is_connected(G)
# Out:
# False

# %%
nx.is_connected(G0)
# Out:
# True

# %%
list(G.nodes())
# Out:
# ['J. Cole',
#  'Meek Mill',
#  'DJ Khaled',
#  'Rick Ross',
#  'Wale',
#  'PARTYNEXTDOOR',
#  '2 Chainz',
#  'Tory Lanez',
#  'Future',
#  'Young Thug',
#  'Jeremih',
#  'Bryson Tiller',
#  'French Montana',
#  'Miguel',
#  '21 Savage',
#  'Metro Boomin',
#  'Migos',
#  'Ty Dolla ign',
#  'Lil Wayne',
#  'Young Money',
#  'ScHoolboy Q',
#  'Ace Hood',
#  'Jay Rock',
#  'Waka Flocka Flame',
#  'Mike WiLL Made-It',
#  'YG',
#  'Kid Ink',
#  'Bas',
#  'AAP Ferg',
#  'VIC MENSA',
#  'Juicy J',
#  'B.o.B',
#  'Big Sean',
#  'Pusha T',
#  'AAP Rocky',
#  'Kid Cudi',
#  'Freddie Gibbs',
#  'Kendrick Lamar',
#  'Nipsey Hussle',
#  'Isaiah Rashad',
#  'Joey Bada',
#  'Chance the Rapper',
#  'Curreny',
#  'Lupe Fiasco',
#  'DJ Drama',
#  'Fabolous',
#  'Jim Jones',
#  'Yo Gotti',
#  'Jeezy',
#  'Jadakiss',
#  'Birdman',
#  'Plies',
#  'T.I.',
#  'T-Pain',
#  'Tyga',
#  'Juelz Santana',
#  'Bun B',
#  'Young Buck',
#  'Slim Thug',
#  'The Diplomats',
#  'Young Dro',
#  'Beanie Sigel',
#  'Lloyd Banks',
#  'Dom Kennedy',
#  'Big K.R.I.T.',
#  'The-Dream',
#  'Lloyd',
#  'August Alsina',
#  'K CAMP',
#  'BJ The Chicago Kid',
#  'Jacquees',
#  'Sevyn Streeter',
#  'TWENTY88',
#  'Teyana Taylor',
#  'Omarion',
#  'Majid Jordan',
#  'Roy Woods',
#  '6LACK',
#  'Yo Trane',
#  'TYuS',
#  'PnB Rock',
#  'dvsn',
#  'Ramriddlz',
#  'Ryan Trey',
#  'Che Ecru',
#  'ELHAE',
#  'Tems',
#  'Eli Sostre',
#  'Vory',
#  'Jhené Aiko',
#  'Quavo',
#  'Rich Homie Quan',
#  'Young Scooter',
#  'Zaytoven',
#  'Gucci Mane',
#  'Preme',
#  'Trey Songz',
#  'Chief Keef',
#  'Lil Durk',
#  'Young Dolph',
#  'NAV',
#  'Gunna',
#  'Lil Yachty',
#  'AAP Mob',
#  'Don Toliver',
#  'Famous Dex',
#  'Kodak Black',
#  'Huncho Jack',
#  'Lil Keed',
#  'SahBabii',
#  'Young Nudy',
#  'Rae Sremmurd',
#  'Desiigner',
#  'Pi’erre Bourne',
#  'UnoTheActivist',
#  'Mario',
#  'Pleasure P',
#  'Pretty Ricky',
#  'J. Holiday',
#  'Sammie',
#  'Keyshia Cole',
#  'Ginuwine',
#  'Baby Bash',
#  'Bow Wow',
#  'Bobby V.',
#  'DaniLeigh',
#  'DeJ Loaf',
#  'Kaash Paige',
#  'Max B',
#  'Uncle Murda',
#  'Vado',
#  'Styles P',
#  'H.E.R.',
#  'Brent Faiyaz',
#  'Ro James',
#  'Syd',
#  'Xavier Omär',
#  'SiR',
#  'Jazmine Sullivan',
#  'Sheck Wes',
#  'Lil Baby',
#  'Trippie Redd',
#  '88GLAM',
#  'Flipp Dinero',
#  'Playboi Carti',
#  'Quality Control',
#  'Rich The Kid',
#  'Comethazine',
#  'Roddy Ricch',
#  'YBN Nahmir',
#  'Bobby Shmurda',
#  'Lil Uzi Vert',
#  'Mustard',
#  'Eric Bellinger',
#  'Mike Jones',
#  'Frank Ocean',
#  'Childish Gambino',
#  'Earl Sweatshirt',
#  'JAY-Z',
#  'KIDS SEE GHOSTS',
#  'Vince Staples',
#  'BROCKHAMPTON',
#  'Baby Keem',
#  'Clipse',
#  'CyHi',
#  'Jay Electronica',
#  'Smoke DZA',
#  'Ab-Soul',
#  'Boldy James',
#  'Danny Brown',
#  'The Cool Kids',
#  'Action Bronson',
#  'The Alchemist',
#  'Benny The Butcher',
#  'WZRD',
#  'Mac Miller',
#  'Denzel Curry',
#  'Young Ratoo',
#  'Flatbush Zombies',
#  'JPEGMAFIA',
#  'Black Hippy',
#  'AAP Twelvyy',
#  'Dizzy Wright',
#  'Tyler The Creator',
#  'Odd Future',
#  'Kevin Abstract',
#  'The Internet',
#  'Solange',
#  'Pharrell Williams',
#  'Domo Genesis',
#  'The Underachievers',
#  'Mick Jenkins',
#  'N.E.R.D',
#  'Spillage Village',
#  'MellowHype',
#  'Mike G',
#  'Lil B',
#  'SpaceGhostPurrp',
#  'Death Grips',
#  'MellowHigh',
#  'Casey Veggies',
#  'BADBADNOTGOOD',
#  'Jet Age of Tomorrow',
#  'King Geedorah',
#  'Madvillain',
#  'Donnie Trumpet  The Social Experiment',
#  'Noname',
#  'Aminé',
#  'Shelley FKA DRAM',
#  'Phony Ppl',
#  'Saba',
#  'Joey Purp',
#  'Taylor Bennett',
#  'Talib Kweli',
#  'Asher Roth',
#  'Blu',
#  'Royce Da 5\'9"',
#  'Big Boi',
#  'Black Star',
#  'Common',
#  'Little Brother',
#  'Mos Def',
#  'Black Thought',
#  'Elzhi',
#  'Joe Budden',
#  'The Roots',
#  'Nas',
#  'Fat Joe',
#  'The Carters',
#  'Cam’ron',
#  'Kanye West',
#  'Memphis Bleek',
#  'Eminem',
#  'Foxy Brown',
#  'The LOX',
#  'DMX',
#  'Busta Rhymes',
#  'Diddy',
#  'The Notorious B.I.G.',
#  'Big Pun',
#  'Method Man',
#  'Mobb Deep',
#  'Injury Reserve',
#  'JulezJZ',
#  'Westside Gunn',
#  'redveil',
#  'KayCyy',
#  '070 Shake',
#  'billy woods',
#  'VRITRA',
#  'Kilo Kish',
#  'Ameer Vann',
#  'Duckwrth',
#  'Choker',
#  'Tierra Whack',
#  'Yeek',
#  'slowthai',
#  'IDK',
#  'Jaden',
#  'Smino',
#  'Kenny Mason',
#  'Roc Marciano',
#  'Statik Selektah',
#  'Aaron May',
#  'Young Stoner Life',
#  'JID',
#  'LUCKI',
#  'Mike Dimes',
#  'NOT',
#  'Ben Reilly',
#  'MadeinTYO',
#  'Ken Carson',
#  'Dreamville',
#  'Kirk Knight',
#  'Childish Major',
#  'Rejjie Snow',
#  'Erick the Architect',
#  'REASON',
#  'Lute',
#  'Kota the Friend',
#  'GoldLink',
#  'Lil Tecca',
#  'Lil Mosey',
#  'YNW Melly',
#  'Blueface',
#  'Lil Gnar',
#  'Lil Pump',
#  'Tay-K',
#  '6ix9ine',
#  'Yeat',
#  'DaBaby',
#  'Yung Pinch',
#  'Tee Grizzley',
#  'Nebu Kiniza',
#  'Ugly God',
#  'Kid Trunks',
#  'Almighty Jay',
#  'Yung Bans',
#  'D. Savage',
#  'Cooliecut',
#  'Matt Ox',
#  'Craig Xen',
#  'Jay Critch',
#  'YoungBoy Never Broke Again',
#  'Quando Rondo',
#  'Moneybagg Yo',
#  'Polo G',
#  'Cordae',
#  'Scorey',
#  'YK Osiris',
#  '24kGoldn',
#  'Luh Kel',
#  'Landon Cube',
#  'iann dior',
#  'Tyla Yaweh',
#  'Yungeen Ace',
#  'NoCap',
#  'A Boogie Wit da Hoodie',
#  'SOB X RBE',
#  'Dbangz',
#  'Yung Tory',
#  'BlocBoy JB',
#  'Quin Nfn',
#  'DDG',
#  'SleazyWorld Go',
#  'Ronny J',
#  'Global Dan',
#  'Fukkit',
#  'Smooky MarGielaa',
#  'Robb Bank',
#  'Lil Xan',
#  'Icy Narco',
#  'Supreme Patty',
#  'City Morgue',
#  'Keith Ape',
#  'Kap G',
#  'Duwap Kaine',
#  'SoFaygo',
#  'AAP ANT',
#  'Remble',
#  'Lancey Foux',
#  'KANKAN',
#  'Autumn!',
#  'Summrs',
#  'tana',
#  'KAHDAMI',
#  'SSGKobe',
#  'Sided',
#  'Oliver Francis',
#  'Fat Nick',
#  'Danger Incorporated',
#  'Paris Shadows',
#  '6 Dogs',
#  'COTIS',
#  'Unodavid',
#  'nothingnowhere.',
#  'The Kid LAROI',
#  'SAINt JHN',
#  'Fetty Wap',
#  'mike.',
#  'Bazzi',
#  'G-Eazy',
#  'Swae Lee',
#  'GASHI',
#  'Arizona Zervas',
#  'gianni  kyle',
#  'Reo Cragun',
#  'THEY.',
#  'anders',
#  'Nbdy',
#  'Cousin Stizz',
#  'Maxo Kream',
#  'HoodRich Pablo Juan',
#  'Tm88',
#  'Offset',
#  'Internet Money',
#  'Bankrol Hayden',
#  'benny blanco',
#  'Dro Kenji',
#  'Lil Skies',
#  'KillBunk',
#  'Fresco Trey',
#  'Amir Obe',
#  'Anfa Rose',
#  'FRVRFRIDAY',
#  'A.CHAL',
#  'Jazz Cartier',
#  'Belly',
#  'YFN Lucci',
#  'Sage The Gemini',
#  'Speaker Knockerz',
#  'Soulja Boy',
#  '24hrs',
#  'BLEU',
#  'Shy Glizzy',
#  'Young M.A',
#  'Cam Meekins',
#  'Luke Christopher',
#  'Chris Webby',
#  'Huey Mack',
#  'Skizzy Mars',
#  'Kid Quill',
#  'Nate Good',
#  'Justin Stone',
#  'Aer',
#  'Hoodie Allen',
#  'Ryan Caraveo',
#  'Sammy Adams',
#  'Witt Lowry',
#  'Bryce Vine',
#  'Cal Scruby',
#  'Radical Something',
#  "The Dean's List",
#  'SonReal',
#  'Madison Beer',
#  'Khalid',
#  'PRETTYMUCH',
#  'Julia Michaels',
#  'Jack  Jack',
#  'ZAYN',
#  "Olivia O'Brien",
#  'Ruel',
#  'Jessie Reyez',
#  'John K',
#  'Chelsea Cutler',
#  'Lauv',
#  'Bea Miller',
#  'MAX',
#  'Marc E. Bassy',
#  'Niall Horan',
#  "Why Don't We",
#  'AJ Mitchell',
#  'Christian French',
#  'Rich Brian',
#  'tobi lou',
#  'EARTHGANG',
#  'Logic',
#  'Futuristic',
#  'Lil Dicky',
#  'mansionz',
#  'Royce Da 5\\\'9"']

# %%
## MODELS THAT RECOMMEND ARTISTS 
import random

# %%
def artist_model(): 
    
    ## 1. Allow the user to choose an artist and whether they want song or artist recommendations  
    Input1 = input("Enter an artist's name:")
    Input2 = input("Enter 'artist' for artist recommendations, 'song' for song recommendations, or 'both' for artist and song recommendations:")
    
    ## 2. Check to make sure the node is in the network. If not, ask for a new artist. 
    if Input1 not in list(G.nodes()): 
        print("Cannot find artist. Please enter another artist's name.")
    
    else: 
        ## 3. Isolate the nodes that are in the same partition as the artist 
        partition_value = best_partition_map[Input1]
        nodes_in_partition = [k for k,v in best_partition_map.items() if float(v) == partition_value]
        #print("partition: ", nodes_in_partition)
    
        ## 4. Get the neighbors for the artist of interest 
        neighbors = list(G.neighbors(Input1))
        #print("neighbors: ", neighbors)
    
        ## 5. Isolate the nodes that are neighbors and in the same partition (maximize relation/similarity)
        nodes_in_partition_set = set(nodes_in_partition)
        neighbors_set = set(neighbors)
        inter_set = nodes_in_partition_set.intersection(neighbors_set)
        list_inter = list(inter_set)
    
        ## 6. Create a subgraph of the most similar nodes 
        H = G.subgraph(list_inter)
        # nx.draw(G, with_labels=True)
    
        ## 7. Get the top three artists with the largest centrality in the subgraph 
        betweenness = nx.centrality.betweenness_centrality(H)
        sorted_vals = dict(sorted(betweenness.items(), key=lambda item: item[1], reverse=True)[:3])
    
        ## 8. If artist is specified as the desired output 
        if Input2 == "artist": 
            sorted_vals = sorted_vals.keys()
            sorted_vals = list(sorted_vals)
            df = pd.DataFrame(sorted_vals)
            df.columns = [''] * len(df.columns)
            print("\n")
            print("Artist Recommendations: ")
            print(df.to_string(index = True))
   
        ## 9. If song is specified as the desired output         
        elif Input2 == "song":
            sorted_vals = sorted_vals.keys()
            sorted_vals = list(sorted_vals)
            node_attributes0 = G.nodes[sorted_vals[0]]['songs']
            node_attributes1 = G.nodes[sorted_vals[1]]['songs']
            node_attributes2 = G.nodes[sorted_vals[2]]['songs']
            node_attributes0 = list(node_attributes0.keys())
            node_attributes1 = list(node_attributes1.keys())
            node_attributes2 = list(node_attributes2.keys())
            joined_list = node_attributes0 + node_attributes1 + node_attributes2
            df = pd.DataFrame(random.sample(joined_list, 10))
            df.columns = [''] * len(df.columns)
            print("\n")
            print("Song Reccomendations: ")
            print(df.to_string(index = True))
       
        ## 10. If both is specified as the desired output  
        elif Input2 == "both":
            sorted_vals = sorted_vals.keys()
            sorted_vals = list(sorted_vals)
            node_attributes0 = G.nodes[sorted_vals[0]]['songs']
            node_attributes1 = G.nodes[sorted_vals[1]]['songs']
            node_attributes2 = G.nodes[sorted_vals[2]]['songs']
            node_attributes0 = list(node_attributes0.keys())
            node_attributes1 = list(node_attributes1.keys())
            node_attributes2 = list(node_attributes2.keys())
            joined_list = node_attributes0 + node_attributes1 + node_attributes2
            df = pd.DataFrame(sorted_vals)
            df.columns = [''] * len(df.columns)
            print("\n")
            print("Artist Recommendations: ")
            print(df.to_string(index = True))
            df1 = pd.DataFrame(random.sample(joined_list, 10))
            df1.columns = [''] * len(df.columns)
            print("\n")
            print("Song Reccomendations: ")
            print(df1.to_string(index = True))

# %%
artist_model()
# Out:
# Enter an artist's name:Kanye West
# Enter 'artist' for artist recommendations, 'song' for song recommendations, or 'both' for artist and song recommendations:both
#
#
# Artist Recommendations:
#
# 0    Vince Staples
# 1  Earl Sweatshirt
# 2    Freddie Gibbs
#
#
# Song Reccomendations:
#
# 0  Yo Love - From "Queen  Slim: The Soundtrack"
# 1              4 Thangs feat. Big Sean  Hit-Boy
# 2                                          Chum
# 3                                      LEMONADE
# 4                                      Thuggin’
# 5                            ARE YOU WITH THAT?
# 6                                    Crime Pays
# 7                            Molasses feat. RZA
# 8                        High feat. Danny Brown
# 9                                     Norf Norf

# %%
# def mutual_friends(G, node_1, node_2,model_type):
#     node_1_set = set(G.neighbors(node_1))
#     node_2_set = set(G.neighbors(node_2))
#     inter_set = node_1_set.intersection(node_2_set)
#     list_inter = list(inter_set)
    
#     if model_type == 'artist': 
#         print(list_inter)
#         return(list_inter)
    
#     else: 
#         print()

# %%
# mutual_friends('Kanye West', 'Drake',artist)

# %%
# mutual_friends('Kanye West', 'Drake',song)
